# %% [markdown]
# Sandbox#1

# %%
Title = input("Enter the title: ")
Author = input("Enter the Author: ")
Price = float(input("Enter Price: "))
StockQuantity = int(input("Enter stockquantity: "))
print(f"Information of the book:\nTitle: {Title}\nAuthor: {Author}\nPrice: {Price}\nStock Quantity: {StockQuantity}")
# Out:
# Information of the book:
# Title: tt
# Author: auth
# Price: 2.33
# Stock Quantity: 2

# %%
print(f"Prize Distribution To Number of students: {53//8}\nLeft: {53%8}")
# Out:
# Prize Distribution To Number of students: 6
# Left: 5

# %%
user = int(input("Enter time in Seconds: "))
print(f"Total Time: {user}\nMinutes: {user//60}\nSeconds: {user%60}")
# Out:
# Total Time:853
# Minutes: 14
# Seconds: 13

# %%
def spendings(Mor=10,Aft=10,Eve=10):
    print(f"Morning spends: {Mor}\nAfternoon spends: {Aft}\nEvening spends{Eve}\nTotal spends: {Mor+Aft+Eve}")
spendings(20,30,40)
# Out:
# Morning spends: 20
# Afternoon spends: 30
# Evening spends40
# Total spends: 90

# %% [markdown]
# Module:

# %%
# %%writefile spending.py

def morningSpends(mor):
    print("Morning Spend: ",mor)

def afternoonSpends(Aft):
    print("Afternoon Spend: ",Aft)

def eveningSpends(Eve):
    print("Evening Spend: ",Eve)

def totalSpend(mor,Aft,Eve):
    print("Total Spend: ",mor+Aft+Eve)
# Out:
# Overwriting spending.py

# %% [markdown]
# Using that Module

# %%
import spending

spending.morningSpends(200)
spending.afternoonSpends(300)
spending.eveningSpends(400)
spending.totalSpend(200,300,400)
# Out:
# Morning Spend:  200
# Afternoon Spend:  300
# Evening Spend:  400
# Total Spend:  900
